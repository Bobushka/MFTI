# %% [markdown]
# # Mashine Learning
#
# Andrew Ng, Stanford
# [Source](https://www.coursera.org/learn/machine-learning/home/welcome)

# %% [markdown]
# ## TABLE OF CONTENTS
# - [Lecture 1: Welcome and Introduction](#Lecture1)
# - [Lecture 2: Linear Regression, Cost function, Gradient Discent](#Lecture2)

# %% [markdown]
# ## Lecture 1: Welcome and Introduction <a name="Lecture1"></a>

# %% [markdown]
# What is Machine Learning?
# 1. machine learning is the field of study that gives computers the ability to learn without being explicitly learned (Arthur Samuel, 1959)
# 2. a computer program is said to learn from experience E with respect to some task T and some performance measure P, if its performance on T, as measured by P, improves with experience E (Tom Mitchell, 1998)

# %% [markdown]
# Machine Learning algorithms:
# 1. Supervise learning (Regression, Classification)
# 2. Unsupervised learning (Clustering, Non-clustering aka "Coctail party")
# 3. Reinforcement learning
# 4. Recommender systems

# %% [markdown]
# ## Lecture 2: Linear Regression, Cost function, Gradient Discent <a name="Lecture2"></a>

# %% [markdown]
# m - number of training examples
# x - input variables / features
# y - output variable / target
# h - hypothesis / target function y' = h(x), where y' is predicted target
# ![Screenshot 2021-03-13 at 20.20.11.png](attachment:15217615-1b66-4b88-9719-f5aa696b57c2.png)

# %% [markdown]
# #### Let's talk about Linear Regression with one variable
